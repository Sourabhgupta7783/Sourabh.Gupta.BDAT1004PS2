# %% [markdown]
# ## Ans - 1

# %%
#**a** was initialized to **0** in function **b()** where another function **c()** is called taking as parameter the value of **a**.

#**a** is at a global scope each call takes the new value of **a** therefore the following happens:
    #1. First call of function **b()** calls function **c()** which takes the current value of **a** which is ``a=0`` and adds 2 i.e it return **a** = 0+2
    #2. Second call of function **b()** calls function **c()** which takes the value of **a** which is ``a=2`` and adds 2 i.e returns **a** = 2+2
    #3. The third call of function **b()** calls function **c()** which takes the value of **a** which is ``a=4`` and adds 2 i.e returns **a** = 4+2
    #4. At this point, the value of **a** is 6 thus **6** is printed out.

# %% [markdown]
# ## Ans - 2

# %%
import os
def fileLength(fname) : 
       try:
            statinfo = os.stat(fname) 
            print(statinfo.st_size) 
   except IOError:
            print("File ", str(fname)," not found") fileLength( 'Untitled7.ipynb') fileLength('idterm.py* )

# %% [markdown]
# ## Ans - 3

# %%
class Marsupial: 
    def _init_(self): 
        self.lst = [] 
        def put_in_pouch(self, item): 
            self.lst.append(item) 
            def pouch_contents(self): 
                print(self.lst) 
                
m = Marsupial() 
m.put_in_pouch('doll') 
m.put_in_pouch('firetruck') 
m.put_in_pouch('kitten')
m.pouch_contents()



class Kangaroo(Marsupial):
    def init_(self,x,y):

        Marsupial.init(self)

        self.x = x

        self.y = y

def jump(self, dx, dy) :
self.x += dx 18 self.y += dy

def _str_(self):
return 'I am a Kangaroo located at coordinates ({}, {})'. format(self.x, self-y) 21

m = Marsupial()
m. put_in_pouch( 'doll')
m. put_in_pouch('firetruck')
m. put_in_pouch("kitten") 
m. pouch_contents ()
k = Kangaroo(0,0)

print(k)

k.put_in_pouch( 'doll')
k.put_in_pouch( 'firetruck') 
k. put_in_pouch( 'kitten")
k. pouch_contents()= [ 'doll', "firetruck', 'kitten'] 
                      
k. jump(1,0)
k. jump (1,0)
k. jump (1,0)
print(k)

# %% [markdown]
# ## Ans 4

# %%
def main( ) :
    collatz(10)
def collatz(x) :
    if x == 1:
    print x
    elif x % 2 == 0:
    print x
    x = x/2 collatz(x)
    else:
    print x
    x =3*x + 1 collatz(x)
if _name == " _main
main( )

# %% [markdown]
# ## Ans 5

# %%
def binary(num) :
if num >= 1:
binary(num // 2) print(num % 2, end = "")
binary(3)

# %% [markdown]
# ## Ans 6

# %%
import re
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
    global getH
    match = re.match(r'h(\d)', tag, re.I)
    if match:
        print(match.group(1))
        getH = int(match.group(1))
        
        def handle_endtag(self, tag):
            match = re.match(r'h(\d)', tag, re.I)
            
            if match:
                getH = 0



def handle_data(self, data):
    if getH > 0:
        tab = getH - 1
        out = "\t"*tab
        print(out + data)



getH = 0
parser = MyHTMLParser()
parser.feed('<html><head><title>Test</title></head>''<body><h1>head1</h1><h2>head2!</h2><h3>head3!</h3></body></html>')

# %% [markdown]
# ## Ans 7

# %%
import os

def fileLength(file_name):
    try:
    length = os.path.getsize(file_name)
    return length
  except FileNotFoundError:
    return "File "+file_name+" not found."

print(fileLength("test.py"))   
print(fileLength("test112233.py"))

import requests from bs4 import BeautifulSoup import re

def
webdir (url, depth, indentation)
if indentation == 0:
print ( (indentation) *"
"+url ) 
       indentation+=1

base url =
"http://reed.cs.depaul.edu/1] 
r = requests.get (url)
soup=
BeautifulSoup(r.content,
"1xml " )

    links=

[base url+link. get ( 'href' ) if "reed.cs.depaul" not in link. get ( "href") else link. get ( 'href') for link in soup. findAll( "a" ) ]

    if len (links) >=0 and depth>=indentation:
      for link in links:
          print ( (indentation) *" "+link)
          webdir( link, depth, indetation)
 else:
return

# %% [markdown]
# ## Ans 8

# %%
# %%sql
# # CREATE THE TABLE NAMED AS 'whether' below
# CREATE TABLE whether
# (
# city varchar(20),
# countrt varchar(25),
# season varchar(55),
# temperature float,
# rainfall float
# );
#
# %%sql
# # NOW INSERT THE DATAS IN TABLE..
# INSERT INTO whether VALUES('Mumbai', 'India', 'Winter', 24.8,5.9),
# ('Mumbai', 'India', 'Spring', 28.4,16.2),
# ('Mumbai', 'India', 'Summer', 27.9,1549.4),
# ('Mumbai', 'India', 'Fall', 27.6,346.0),
# ('London', 'United kingdom', 'Winter', 4.2,207.7),
# ('London', 'United kingdom', 'Spring', 8.3,169.6),
# ('London', 'United kingdom','Summer', 15.7,157.0),
# ('London', 'United kingdom','Fall', 10.4,218.5),
# ('Cairo', 'Egypt','Winter', 13.6,16.5),
# ('Cairo', 'Egypt', 'Spring', 20.7,6.5);
#
# %%sql
# select * from whether;
#
# OUTPUT: TABLE
#
# #ANS (a)
#
# %%sql
# # WILL RETURN ALL TEMPERATURE DATA
# select temperature from whether;
#
# #ANS (b)
#
# # CITIES, BUT WITHOUT REPITATION
# %%sql
# select distinct city from whether;
#
# #ANSWER (c)
#
# #RECORDS FOR INDIA
# %%sql
# select * from whether where countrt =='India';
#
# #ANSWER (D):
#
# # RECORDS FOR SEASON FALL
# %%sql
# select * from whether where season == 'Fall';
#
# #ANSWER (e)
#
# #WILL RETURN CITY, COUNTRY, SEASON FOR RAINFALL IN BETWEEN 200 AND 400
# %%sql
# select city, countrt, season from whether where rainfall between 200 and 400
#
# #ANSWER (F)
#
# #CITY AND COUNTRY FOR FALL SEASON WHERE TEMP > 20
# %%sql
# select city, countrt from whether where season == 'Fall' and temperature > 20 order by temperature ASC;
#
# #ANSWER (G)
#
# #ANNUAL RAINFALL FOR CAIRO CITY
# %%sql
# select sum(rainfall) AS annual_rainfall from whether where city == 'Cairo';
#
# #ANSWER (H)
#
# # ANNUAL RAINFALL FOR EACH SEASON
# %%sql
# select season, sum(rainfall) AS annual_rainfall from whether group by season ;

# %% [markdown]
# ## Ans 9

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

#a

def Upper(words):
    for i in range(len(words)):
        #convert every word in uppercase
        words[i]=words[i].upper()
    return words

#b
def Lower(words):
    for i in range(len(words)):
        #convert all words in lowercase
        words[i]=words[i].lower()

    return words

#c
def Length(words):
    for i in range(len(words)):
        words[i]=len(words[i])
    return words

list_Length=Length(words)
print(list_Length)

#d
def Low_Up_Len(words):
    list=[] 
    temp=[] 
    for i in range(len(words)):
        temp.append(words[i].upper())
        temp.append(words[i].lower())
        temp.append(len(words[i]))
        list.append(temp)
        temp=[]


    return list

list=Low_Up_Len(words)
print(list)

#e
print([x for x in words if len(x)>=4])
